# %%
import os
import torch
from torchvision import datasets, transforms
from torch.utils.data import Dataset

# %%
data_dir = "E:/projects/fake-ai-detection/data/genimage/archive/imagenet_ai_0419_biggan"

# %%
train_dir = os.path.join(data_dir, 'train')

# %%
images = datasets.ImageFolder(train_dir, transform=transforms.ToTensor())

# %%
len(images)
# Out:
# 4000
